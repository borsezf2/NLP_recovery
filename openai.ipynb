# %%
from openai import OpenAI
import time
import os
from ratelimit import limits, sleep_and_retry


# Set your OpenAI API key as an environment variable
os.environ["OPENAI_API_KEY"] = os.getenv('GIT_OPENAPI_KEY')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 from ratelimit import limits, sleep_and_retry
#       7 # Set your OpenAI API key as an environment variable
# ----> 8 os.environ["OPENAI_API_KEY"] = os.getenv('GIT_OPENAPI_KEY')
#
# File /usr/lib/python3.8/os.py:680, in _Environ.__setitem__(self, key, value)
#     678 def __setitem__(self, key, value):
#     679     key = self.encodekey(key)
# --> 680     value = self.encodevalue(value)
#     681     self.putenv(key, value)
#     682     self._data[key] = value
#
# File /usr/lib/python3.8/os.py:750, in _createenviron.<locals>.encode(value)
#     748 def encode(value):
#     749     if not isinstance(value, str):
# --> 750         raise TypeError("str expected, not %s" % type(value).__name__)
#     751     return value.encode(encoding, 'surrogateescape')
#
# TypeError: str expected, not NoneType

# %%
# Define rate limit: 3 calls per minute
CALLS = 3
RATE_LIMIT = 60

def measure_time(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        print(f"{func.__name__} time: {end_time - start_time:.2f} seconds")
        return result
    return wrapper

@sleep_and_retry
@limits(calls=CALLS, period=RATE_LIMIT)
def generate_text(prompt, max_tokens=400, model="gpt-3.5-turbo"):
# def generate_text(prompt, max_tokens=400, model="gpt-4o"):
    client = OpenAI()
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "i will give you a problem related to a distributed application, resolve it and give a python code to resolve it so that no human input is needed."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=max_tokens,
    )
    return response.choices[0].message.content.strip()

# %%
# Define your prompt

# Ask a coding question
prompt = '''
code for gcd in python
'''
# Example usage
# prompt = "What is the capital of France?"
try:
    for i in range(1):  # Try to make 5 calls
        result = generate_text(prompt)
        print(f"Call {i+1}: {result}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Call 1: To address your issue of an unwanted process consuming a lot of CPU usage on a remote host, you can use Python with the `paramiko` library to automate the process of logging into the remote host, identifying the process, and terminating it.
#
# ### Steps:
# 1. **Install Paramiko Library**: If you haven’t already, you will need to install the `paramiko` library.
#     ```sh
#     pip install paramiko
#     ```
#
# 2. **Create the Python Script**: The script will:
#     - Connect to the remote host using SSH.
#     - Identify the process consuming the most CPU.
#     - Terminate the process.
#
# Here's a complete Python script to achieve this:
#
# ```python
# import paramiko
# import sys
#
# def find_and_kill_cpu_hogging_process(host, username, password):
#     try:
#         # Create the SSH client
#         ssh = paramiko.SSHClient()
#         ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
#
#         # Connect to the host
#         ssh.connect(hostname=host, username=username, password=password)
#
#         # Command to find the process using the most CPU
#         find_process_cmd = "ps aux --sort=-%cpu | awk 'NR==2{print $2}'"
#         stdin, stdout, stderr = ssh.exec_command(find_process_cmd)
#
#         # Get the PID of the process
#         pid = stdout.read().decode().strip()
#
#         if pid:
#             print(f"Terminating process with PID: {pid}")
#             # Command to kill the process
#             kill_process_cmd = f"kill -9 {pid}"
#             ssh.exec_command(kill_process_cmd)
#             print(f"Process {pid} terminated successfully.")
#         else:
#             print("No process found to terminate.")
#
#         # Close the SSH connection
#         ssh.close()
#
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         sys.exit(1)

# %%
# # gpt3.5 turbo
# Call 1: ```python
# import paramiko

# host = "10.5.16.213"
# port = 22
# username = "harsh"
# password = "123"

# command = "pkill -f 'unwanted_process'"

# ssh_client = paramiko.SSHClient()
# ssh_client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
# ssh_client.connect(host, port, username, password)

# stdin, stdout, stderr = ssh_client.exec_command(command)

# ssh_client.close()


# # gpt4o
# Call 1: ```python
# import paramiko
# import re
# import logging

# # Configure logging
# logging.basicConfig(filename='logfile.log', level=logging.DEBUG, 
#                     format='%(asctime)s:%(levelname)s:%(message)s')

# def handle_unwanted_process(host, username, password):
#     try:
#         # Connect to the server
#         ssh = paramiko.SSHClient()
#         ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
#         ssh.connect(host, username=username, password=password)
        
#         # Run top command to get process list
#         stdin, stdout, stderr = ssh.exec_command('ps -eo pid,pcpu,comm --sort=-pcpu | head -n 6')
#         process_list = stdout.read().decode().strip().split('\n')[1:]
        
#         # Find the process with highest CPU usage
#         for process in process_list:
#             process_details = re.split(r'\s+', process.strip())
#             pid = process_details[0]
#             cpu = float(process_details[1])
#             command = process_details[2]
            
#             # Here, you can define the threshold for CPU usage
#             if cpu > 10:  # Assuming 10% CPU usage as threshold 
#                 # Kill the process that is consuming high CPU
#                 kill_command = f'kill -9 {pid}'
#                 ssh.exec_command(kill_command)
#                 logging.info(f'Killed process {command} with PID {pid} using {cpu}% CPU')
#                 break
        
#         ssh.close()
#     except Exception as e:
#         logging.error(f"Error: {str(e)}")

# # Host details
# host = "10.5.16.213"
# username = "harsh"
# password = "123"

# handle_unwanted_process(host, username, password)
# ```
